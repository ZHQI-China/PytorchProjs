# %%
with open('../data/Mao.txt','r',encoding='utf-8') as f:
    text = f.read()
len(text),text[:100]
# Out:
# (1737172,
#  '中国社会各阶级的分析\n\n（一九二五年十二月一日）\n\n谁是我们的敌人？谁是我们的朋友？这个问题是革命的首要问题。中国过去一切革命斗争成效甚少，其基本原因就是因为不能团结真正的朋友，以攻击真正的敌人。革命')
