# %% [markdown]
# ![image.png](attachment:image.png)

# %%
zhs = open('data/names1/names1.txt','r').read().splitlines()
pinyins = open('data/names1/names1_pinyin_components.txt','r').read().splitlines()
pinyins_to_chars = open('data/names1/pinyin_components_to_hanzi_chars1.txt','r').read().splitlines()

i=0
for zh,p,ch in zip(zhs[:10],pinyins[:10],pinyins_to_chars[:10]):
    print(f'{i:02d}: {zh:5} {p:25} {ch}')
    i+=1

len(zhs),len(pinyins),len(pinyins_to_chars)
# Out:
# 00: 倪|子宁  n i | z i n ing           n i	倪
# 01: 宋|云深  s ong | y un sh en        z i	子
# 02: 尤|听澜  y ou | t ing l an         n ing	宁
# 03: 唐|承安  t ang | ch eng _ an       s ong	宋
# 04: 龙|长宁  l ong | zh ang n ing      y un	云 韵
# 05: 田|清玄  t ian | q ing x uan       sh en	深 沈 申
# 06: 柯|川   k e | ch uan              y ou	尤 游
# 07: 郑|灵微  zh eng | l ing w ei       t ing	听
# 08: 任|瑶音  r en | y ao y in          l an	澜 岚 兰
# 09: 汪|音   w ang | y in              t ang	唐 棠 汤
# (12000, 12000, 188)

# %%
# set(''.join(pinyins))
tokens = [p.split() for p in pinyins]
token_list = sorted({'.'} | {t for token in tokens for t in token})
token_list_len = len(token_list)

stoi = {s:i for i,s in enumerate(token_list)}
itos = {i:s for i,s in enumerate(token_list)}


print(pinyins[:2])
print(tokens[:2])
print(sorted(set([t for token in tokens[:2] for t in token])))

print(itos)
print(stoi)
print(token_list_len)
# Out:
# ['n i | z i n ing', 's ong | y un sh en']
# [['n', 'i', '|', 'z', 'i', 'n', 'ing'], ['s', 'ong', '|', 'y', 'un', 'sh', 'en']]
# ['en', 'i', 'ing', 'n', 'ong', 's', 'sh', 'un', 'y', 'z', '|']
# {0: '.', 1: '_', 2: 'a', 3: 'ai', 4: 'an', 5: 'ang', 6: 'ao', 7: 'b', 8: 'c', 9: 'ch', 10: 'd', 11: 'e', 12: 'ei', 13: 'en', 14: 'eng', 15: 'f', 16: 'g', 17: 'h', 18: 'i', 19: 'ia', 20: 'ian', 21: 'iang', 22: 'iao', 23: 'ie', 24: 'in', 25: 'ing', 26: 'iong', 27: 'iu', 28: 'j', 29: 'k', 30: 'l', 31: 'm', 32: 'n', 33: 'o', 34: 'ong', 35: 'ou', 36: 'p', 37: 'q', 38: 'r', 39: 's', 40: 'sh', 41: 't', 42: 'u', 43: 'ua', 44: 'uai', 45: 'uan', 46: 'uang', 47: 'ue', 48: 'ui', 49: 'un', 50: 'uo', 51: 'v', 52: 'w', 53: 'x', 54: 'y', 55: 'z', 56: 'zh', 57: '|'}
# {'.': 0, '_': 1, 'a': 2, 'ai': 3, 'an': 4, 'ang': 5, 'ao': 6, 'b': 7, 'c': 8, 'ch': 9, 'd': 10, 'e': 11, 'ei': 12, 'en': 13, 'eng': 14, 'f': 15, 'g': 16, 'h': 17, 'i': 18, 'ia': 19, 'ian': 20, 'iang': 21, 'iao': 22, 'ie': 23, 'in': 24, 'ing': 25, 'iong': 26, 'iu': 27, 'j': 28, 'k': 29, 'l': 30, 'm': 31, 'n': 32, 'o': 33, 'ong': 34, 'ou': 35, 'p': 36, 'q': 37, 'r': 38, 's': 39, 'sh': 40, 't': 41, 'u': 42, 'ua': 43, 'uai': 44, 'uan': 45, 'uang': 46, 'ue': 47, 'ui': 48, 'un': 49, 'uo': 50, 'v': 51, 'w': 52, 'x': 53, 'y': 54, 'z': 55, 'zh': 56, '|': 57}
# 58

# %%
# 训练集 80% -> 优化模型权重
# 验证集 10% -> 调整超参数
# 测试集 10% -> 测试模型泛化性和准确率
import torch
import torch.nn.functional as F

block_size = 3 # 上下文长度
def build_dataset(data):
    X,Y = [],[]
    for t in data:
        # print(['.']*block_size + t + ['.'])
        # print(t + ['.'])

        str1 = ['.']*block_size + t + ['.']
        str2 = t + ['.']

        i=0
        for _,y in zip(str1,str2):
            # print(str1[i:i+block_size],y)
            # print([stoi[str1[j]] for j in range(i,i+block_size)],stoi[y])
            X.append([stoi[str1[j]] for j in range(i,i+block_size)])
            Y.append(stoi[y])
            i+=1


    X=torch.tensor(X)
    Y=torch.tensor(Y)
    print(X.shape,Y.shape,X.dtype,Y.dtype)
    return X,Y

import random
random.seed(0)
random.shuffle(tokens)
n1 = int(0.8*len(tokens))
n2 = int(0.9*len(tokens))

Xtr,Ytr   = build_dataset(tokens[:n1])
Xdev,Ydev = build_dataset(tokens[n1:n2])
Xte,Yte   = build_dataset(tokens[n2:])
# Out:
# torch.Size([74388, 3]) torch.Size([74388]) torch.int64 torch.int64
# torch.Size([9262, 3]) torch.Size([9262]) torch.int64 torch.int64
# torch.Size([9266, 3]) torch.Size([9266]) torch.int64 torch.int64

# %%
embedding_dim = 2
hidden_dim = 100
batch_size = 32

g = torch.Generator().manual_seed(0)
E = torch.randn((token_list_len, embedding_dim),generator=g)
W1 = torch.randn((block_size*embedding_dim, hidden_dim),generator=g)
b1 = torch.randn(hidden_dim,generator=g)
W2 = torch.randn((hidden_dim,token_list_len),generator=g)
b2 = torch.randn(token_list_len,generator=g)

parameters=[E,W1,b1,W2,b2]
for p in parameters:
    p.requires_grad = True
lr_base = 0.3

# %%
def get_lr(lr_base,i,iter_count):
    if i<iter_count/2:
        return lr_base
    if i>iter_count-iter_count/4:
        return lr_base/100
    return lr_base/10

get_lr(0.3,0,200000),get_lr(0.3,99999,200000),get_lr(0.3,100000,200000),get_lr(0.3,150000,200000),get_lr(0.3,150001,200000)
# Out:
# (0.3, 0.3, 0.03, 0.03, 0.003)

# %%
# train
iter_count = 200000
stepi = []
lossi = []
for i in range(iter_count):
    # forward pass
    batch_idxs = torch.randint(0,Xtr.shape[0],(batch_size,))
    emb = E[Xtr[batch_idxs]]
    h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
    logits = h@W2+b2
    loss = F.cross_entropy(logits,Ytr[batch_idxs])

    #backward pass
    for p in parameters:
        p.grad = None
    loss.backward()

    # update
    lr = get_lr(lr_base,i,iter_count)
    for p in parameters:
        p.data += -lr*p.grad
    
    # track stats
    stepi.append(i)
    lossi.append(loss.item())

    # print
    if(i%1000==0):
        print(f'{i:6d}: loss={loss.item()}')
# Out:
#      0: loss=19.70985221862793
#   1000: loss=2.3815720081329346
#   2000: loss=2.1230640411376953
#   3000: loss=1.7285488843917847
#   4000: loss=2.2592012882232666
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(stepi,lossi)

emb = E[Xtr]
h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
logits = h@W2+b2
loss = F.cross_entropy(logits,Ytr)
print(loss)

emb = E[Xdev]
h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
logits = h@W2+b2
loss = F.cross_entropy(logits,Ydev)
loss
# Out:
# tensor(1.3407, grad_fn=<NllLossBackward0>)
# tensor(1.3655, grad_fn=<NllLossBackward0>)

# %%
plt.figure(figsize=(8,8))
plt.scatter(E[:,0].data,E[:,1].data,s=300)
for i in range(E.shape[0]):
    plt.text(E[i,0].item(),E[i,1].item(),itos[i],ha='center',va='center',color='white')
plt.grid('minor')

# %%
# 采样
g = torch.Generator().manual_seed(0)

samples=[]
names=[]
for i in range(100):
    has_first_name = False
    out = []
    context = [0]*3  #'...'起始
    # print(context)
    while True:
        emb = E[torch.tensor([context])]

        # print(emb)

        h = torch.tanh(emb.view(1,-1)@W1+b1)
        # print(h.shape)
        logits = h@W2+b2
        probs = F.softmax(logits,dim=1)
        # print(probs.shape, probs[0].sum())
        ix = torch.multinomial(probs,num_samples=1,replacement=True,generator=g).item()
        char = itos[ix]
        # 确保每次采样一个姓氏一个名
        if char=='.':
            if has_first_name:
                break
            else:
                continue
        if char=='|':
            if not has_first_name:
                has_first_name = True
            else:
                break 
        context = context[1:]+[ix]       
        out.append(char)
        
        # #小于5个字
        # if len(out)>=4*2 :
        #     break
    samples.append(out)
    

i=0        
for o in samples:
    print(f'{i:03d}:{o}')
    i+=1
# Out:
# 000:['t', 'an', '|', 'zh', 'ang', 'g', 'eng']
# 001:['sh', 'i', '|', 'm', 'o', 'b', 'ai']
# 002:['l', 'i', '|', 'x', 'uan', 'h', 'eng']
# 003:['zh', 'eng', '|', 'h', 'uai', 'n', 'ing']
# 004:['b', 'ai', '|', 'w', 'an']
# 005:['d', 'ai', '|', 'q', 'ing', 'q', 'iu']
# 006:['d', 'uan', '|', 'm', 'ing', 'zh', 'ao']
# 007:['x', 'ue', '|', 'y', 'an']
# 008:['j', 'iang', '|', 'y', 'u', 'w', 'en']
# 009:['m', 'o', '|', 'y', 'an']
# 010:['t', 'ong', '|', 'x', 'ing', 'q', 'ing']
# 011:['q', 'u', '|', 'zh', 'ang', '_', 'an']
# 012:['b', 'ai', 'l', 'i', '|', 'l', 'an', 'n', 'ing']
# 013:['l', 'in', '|', 'x', 'uan', 'y', 'u']
# 014:['l', 'i', '|', 'l', 'an']
# 015:['p', 'eng', '|', 'x', 'uan', 'y', 'ue']
# 016:['y', 'in', '|', 'y', 'ao', 'g', 'uang']
# 017:['q', 'ian', '|', 'w', 'an']
# 018:['t', 'ian', '|', 'q', 'ing', 'y', 'uan']
# 019:['x', 'ue', '|', 'j', 'ing', 'x', 'ing']
# 020:['l', 'uo', '|', 'j', 'ing', 'x', 'ing']
# 021:['l', 'u', '|', 'zh', 'ang', 'g', 'eng']
# 022:['f', 'eng', '|', 'q', 'ing', 'x', 'iao']
# 023:['f', 'u', '|', 'q', 'ing', 'n', 'ing']
# 024:['k', 'e', '|', 'z', 'i', 'y', 'uan']
# 025:['y', 'ao', '|', 'j', 'ing', 'm', 'ing']
# 026:['zh', 'ao', '|', 'g', 'ui', 'ch', 'en']
# 027:['l', 'u', '|', 'zh', 'ao', 'h', 'ua']
# 028:['m', 'u', '|', 'q', 'ing', 'm', 'ing']
# 029:['k', 'ong', '|', 'h', 'uan']
# 030:['g', 'e', '|', 'x', 'ue', 't', 'ang']
# 031:['x', 'iao', '|', 'x', 'uan', 'm', 'ing']
# 032:['b', 'i', '|', 'm', 'ing', 'y', 'uan']
# 033:['x', 'iao', '|', 't', 'ing', 'f', 'eng']
# 034:['d', 'i', '|', 'z', 'i', 'n', 'ing']
# 035:['zh', 'ong', 'l', 'i', '|', 'zh', 'ou']
# 036:['h', 'uang', '|', 'l', 'an', 'n', 'ing']
# 037:['d', 'ing', '|', 'q', 'ing']
# 038:['c', 'ao', '|', 'q', 'ing', 't', 'ang']
# 039:['j', 'ia', '|', 'l', 'ing', 'q', 'iu']
# 040:['x', 'u', '|', 't', 'ing', 'l', 'an']
# 041:['y', 'in', '|', 'sh', 'ou', 'zh', 'en']
# 042:['zh', 'u', '|', 'y', 'un', 'y', 'uan']
# 043:['_', 'u', '|', 'z', 'i', 'm', 'o']
# 044:['w', 'u', '|', 'y', 'un', 'j', 'i']
# 045:['y', 'u', 'w', 'en', '|', 'g', 'ui', 'h', 'ong']
# 046:['sh', 'en', '|', 'y', 'ue']
# 047:['h', 'u', '|', 'l', 'an', 'y', 'ue']
# 048:['s', 'un', '|', 'x', 'iu', 'r', 'an']
# 049:['l', 'i', '|', 'x', 'ing', 'zh', 'ou']
# 050:['ch', 'eng', '|', 'x', 'i']
# 051:['k', 'ang', '|', 'sh', 'en']
# 052:['h', 'uang', 'f', 'u', '|', 'y', 'ao', 'y', 'ue']
# 053:['x', 'ue', '|', 'y', 'ao', 'g', 'uang']
# 054:['s', 'ong', '|', 'y', 'u', 'q', 'ing']
# 055:['j', 'in', '|', 'ch', 'eng', 'n', 'ing']
# 056:['y', 'in', '|', 'y', 'un', 'y', 'uan']
# 057:['y', 'un', '|', 'l', 'ing', 'y', 'ue']
# 058:['m', 'eng', '|', 'w', 'u', 'y', 'ang']
# 059:['d', 'ong', '|', 'y', 'un', 'ch', 'e']
# 060:['m', 'a', '|', 'x', 'ue', 't', 'ang']
# 061:['s', 'un', '|', 'l', 'an', 'w', 'ei']
# 062:['x', 'ia', '|', 'y', 'un', 'q', 'i']
# 063:['y', 'e', '|', 'zh', 'i', 'm', 'ing']
# 064:['f', 'an', '|', 'g', 'ui', 'y', 'ue']
# 065:['c', 'ai', '|', 'y', 'ao', 'q', 'ing']
# 066:['zh', 'uang', '|', 'y', 'ao', 'l', 'an']
# 067:['h', 'e', '|', 'z', 'i', 'q', 'ing']
# 068:['l', 'an', '|', 'w', 'u', 'j', 'iu']
# 069:['zh', 'an', '|', 'j', 'ing']
# 070:['y', 'u', '|', 'zh', 'ang', 'g', 'eng']
# 071:['d', 'ong', 'f', 'ang', '|', 'z', 'i', 'y', 'uan']
# 072:['l', 'an', '|', 'sh', 'ao', 'b', 'ai']
# 073:['y', 'an', '|', 'x', 'ing', 'l', 'in']
# 074:['h', 'uang', '|', 'z', 'i', 'j', 'in']
# 075:['zh', 'u', 'g', 'e', '|', 'x', 'ing', 'zh', 'ou']
# 076:['b', 'o', '|', 'h', 'uai', 'j', 'in']
# 077:['g', 'u', '|', 'w', 'an', 't', 'ang']
# 078:['t', 'ian', '|', 'h', 'an', 'zh', 'ang']
# 079:['y', 'uan', '|', 'y', 'an']
# 080:['w', 'en', 'r', 'en', '|', 'l', 'ing', 'w', 'ei']
# 081:['d', 'uan', 'm', 'u', '|', 't', 'ing', 'x', 'ue']
# 082:['z', 'eng', '|', 'h', 'ang']
# 083:['d', 'ing', '|', 'x', 'uan', 'zh', 'en']
# 084:['zh', 'u', '|', 'sh', 'ao', 'b', 'ai']
# 085:['d', 'ong', 'g', 'uo', '|', 'w', 'u', 'ch', 'en']
# 086:['t', 'ao', '|', 'q', 'ing', 'y', 'an']
# 087:['t', 'ang', '|', 'y', 'u', 'w', 'en']
# 088:['r', 'en', '|', 'x', 'ing', 'h', 'e']
# 089:['zh', 'uang', 'l', 'i', '|', 'q', 'ing', 'y', 'u']
# 090:['sh', 'i', 'm', 'a', '|', 'z', 'i', 'm', 'o']
# 091:['l', 'iu', '|', 'y', 'an']
# 092:['c', 'ong', '|', 'r', 'an']
# 093:['zh', 'ao', '|', 'q', 'ing', 't', 'ang']
# 094:['g', 'ong', 's', 'un', '|', 'y', 'un', 'x', 'iu']
# 095:['h', 'e', '|', 'z', 'i', 'm', 'o']
# 096:['y', 'uan', '|', 'j', 'ing', 'h', 'ong']
# 097:['k', 'ong', '|', 'x', 'ing', 'h', 'e']
# 098:['sh', 'eng', '|', 'zh', 'ang', 'f', 'eng']
# 099:['l', 'i', '|', 'x', 'uan', 'h', 'eng']

# %%
# 解码成中文
INITIALS = {
    '_', 'b','p','m','f','d','t','n','l','g','k','h',
    'j','q','x','r','z','c','s','y','w','zh','ch','sh'
}

FINALS = {
    'a','o','e','i','u','v',
    'ai','ei','ui','ao','ou','iu','ie','ue','er',
    'an','en','in','un','vn',
    'ang','eng','ing','ong',
    'ia','iao','ian','iang','iong',
    'ua','uo','uai','uan','uang'
}
def is_valid(tokens):
    
    # 只能有一个姓氏
    if tokens.count('|') != 1:
        return False

    # 必须有一个姓氏和一个名
    sep = tokens.index('|')
    if sep == 0 or sep == len(tokens) - 1:
        return False

    # 确保声母和韵母配对
    parts = tokens[:sep] + tokens[sep + 1:]
    if len(parts) % 2 != 0:
        return False

    # # 小于5个汉字
    # if len(parts)/2 > 5:
    #     return False

    # 必须在声韵表中
    for i in range(0, len(parts), 2):
        if parts[i] not in INITIALS:
            return False
        if parts[i + 1] not in FINALS:
            return False

    return True


i=0
for flag in [is_valid(o) for o in samples]:
    if not flag:
        print(f'{i}: {samples[i]}')
    
    i+=1

# %%
import random
def load_component_char_mapping(path):
    mapping = {}

    with open(path, encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            key, chars_text = line.split('\t', 1)
            mapping[key] = chars_text.split()

    return mapping

mapping = load_component_char_mapping('data/names1/pinyin_components_to_hanzi_chars1.txt')
print(len(mapping),mapping.get('h an'))

def samples_to_names(samples, mapping, rng=random):
    for i, tokens in enumerate(samples):
        try:
            sep = tokens.index('|')
        except ValueError:
            # 1. 没有 '|' 符号，属于严重格式错误，保留 INVALID
            print(f'{i:03d}: [<Invaild 1: No \'|\' >] --> [<None>]')
            continue

        left_part, right_part = [], []
        valid = True

        for side in (tokens[:sep], tokens[sep + 1:]):
            # 2. 长度不是偶数，属于格式错误，保留 INVALID
            if len(side) % 2 != 0:
                valid = False
                break
            
            l_chars, r_chars = [], []
            for j in range(0, len(side), 2):
                pinyin = side[j] + side[j + 1]
                key = f"{side[j]} {side[j + 1]}"
                choices = mapping.get(key)
                
                # 如果 mapping 里面没有，直接用原始拼音
                if choices:
                    l_chars.append(rng.choice(choices))
                else:
                    l_chars.append(pinyin)
                    
                r_chars.append(pinyin)
            
            left_part.append(''.join(l_chars))
            right_part.append(' '.join(r_chars))

        if not valid:
            print(f'{i:03d}: [<Invaild 2: 声韵母不匹配>] --> [<None>]')
        else:
            print(f'{i:03d}: [{" | ".join(right_part):25}] --> [{"|".join(left_part)}]')

samples_to_names(samples, mapping)
# Out:
# 188 ['含', '韩', '涵', '寒']
# 000: [tan | zhang geng         ] --> [覃|章庚]
# 001: [shi | mo bai             ] --> [施|墨柏]
# 002: [li | xuan heng           ] --> [离|玄衡]
# 003: [zheng | huai ning        ] --> [郑|怀宁]
# 004: [bai | wan                ] --> [百|晚]
# 005: [dai | qing qiu           ] --> [戴|青邱]
# 006: [duan | ming zhao         ] --> [段|明赵]
# 007: [xue | yan                ] --> [薛|晏]
# 008: [jiang | yu wen           ] --> [姜|俞文]
# 009: [mo | yan                 ] --> [墨|言]
# 010: [tong | xing qing         ] --> [童|星清]
# 011: [qu | zhang _an           ] --> [曲|张安]
# 012: [bai li | lan ning        ] --> [柏里|澜宁]
# 013: [lin | xuan yu            ] --> [林|玄玉]
# 014: [li | lan                 ] --> [里|兰]
# 015: [peng | xuan yue          ] --> [彭|玄越]
# 016: [yin | yao guang          ] --> [殷|瑶光]
# 017: [qian | wan               ] --> [钱|万]
# 018: [tian | qing yuan         ] --> [田|青渊]
# 019: [xue | jing xing          ] --> [薛|璟邢]
# 020: [luo | jing xing          ] --> [洛|惊行]
# 021: [lu | zhang geng          ] --> [鲁|张耿]
# 022: [feng | qing xiao         ] --> [凤|晴霄]
# 023: [fu | qing ning           ] --> [傅|青宁]
# 024: [ke | zi yuan             ] --> [柯|子辕]
# 025: [yao | jing ming          ] --> [遥|璟冥]
# 026: [zhao | gui chen          ] --> [昭|归尘]
# 027: [lu | zhao hua            ] --> [芦|赵华]
# 028: [mu | qing ming           ] --> [木|青冥]
# 029: [kong | huan              ] --> [空|欢]
# 030: [ge | xue tang            ] --> [歌|雪汤]
# 031: [xiao | xuan ming         ] --> [萧|玄冥]
# 032: [bi | ming yuan           ] --> [毕|冥元]
# 033: [xiao | ting feng         ] --> [霄|听冯]
# 034: [di | zi ning             ] --> [翟|子宁]
# 035: [zhong li | zhou          ] --> [钟黎|周]
# 036: [huang | lan ning         ] --> [黄|岚宁]
# 037: [ding | qing              ] --> [丁|晴]
# 038: [cao | qing tang          ] --> [曹|晴唐]
# 039: [jia | ling qiu           ] --> [贾|灵秋]
# 040: [xu | ting lan            ] --> [许|听兰]
# 041: [yin | shou zhen          ] --> [殷|守甄]
# 042: [zhu | yun yuan           ] --> [竹|韵元]
# 043: [_u | zi mo               ] --> [_u|子莫]
# 044: [wu | yun ji              ] --> [舞|云纪]
# 045: [yu wen | gui hong        ] --> [羽文|归鸿]
# 046: [shen | yue               ] --> [深|越]
# 047: [hu | lan yue             ] --> [胡|岚岳]
# 048: [sun | xiu ran            ] --> [孙|修然]
# 049: [li | xing zhou           ] --> [离|邢舟]
# 050: [cheng | xi               ] --> [成|席]
# 051: [kang | shen              ] --> [康|沈]
# 052: [huang fu | yao yue       ] --> [黄甫|摇岳]
# 053: [xue | yao guang          ] --> [薛|摇光]
# 054: [song | yu qing           ] --> [宋|尉晴]
# 055: [jin | cheng ning         ] --> [金|承宁]
# 056: [yin | yun yuan           ] --> [殷|韵远]
# 057: [yun | ling yue           ] --> [韵|灵月]
# 058: [meng | wu yang           ] --> [孟|吴杨]
# 059: [dong | yun che           ] --> [董|云澈]
# 060: [ma | xue tang            ] --> [马|薛棠]
# 061: [sun | lan wei            ] --> [孙|兰魏]
# 062: [xia | yun qi             ] --> [夏|韵起]
# 063: [ye | zhi ming            ] --> [叶|执明]
# 064: [fan | gui yue            ] --> [范|桂越]
# 065: [cai | yao qing           ] --> [蔡|遥晴]
# 066: [zhuang | yao lan         ] --> [庄|姚岚]
# 067: [he | zi qing             ] --> [禾|子晴]
# 068: [lan | wu jiu             ] --> [岚|吴咎]
# 069: [zhan | jing              ] --> [詹|景]
# 070: [yu | zhang geng          ] --> [宇|长耿]
# 071: [dong fang | zi yuan      ] --> [董方|子渊]
# 072: [lan | shao bai           ] --> [岚|少柏]
# 073: [yan | xing lin           ] --> [颜|行林]
# 074: [huang | zi jin           ] --> [皇|子靳]
# 075: [zhu ge | xing zhou       ] --> [竹歌|邢舟]
# 076: [bo | huai jin            ] --> [卜|怀靳]
# 077: [gu | wan tang            ] --> [谷|婉唐]
# 078: [tian | han zhang         ] --> [田|寒长]
# 079: [yuan | yan               ] --> [袁|晏]
# 080: [wen ren | ling wei       ] --> [闻任|灵魏]
# 081: [duan mu | ting xue       ] --> [端牧|听薛]
# 082: [zeng | hang              ] --> [曾|珩]
# 083: [ding | xuan zhen         ] --> [丁|玄甄]
# 084: [zhu | shao bai           ] --> [竹|少百]
# 085: [dong guo | wu chen       ] --> [动郭|吴尘]
# 086: [tao | qing yan           ] --> [陶|青严]
# 087: [tang | yu wen            ] --> [汤|羽文]
# 088: [ren | xing he            ] --> [人|邢贺]
# 089: [zhuang li | qing yu      ] --> [庄黎|晴宇]
# 090: [shi ma | zi mo           ] --> [史马|子莫]
# 091: [liu | yan                ] --> [刘|言]
# 092: [cong | ran               ] --> [丛|然]
# 093: [zhao | qing tang         ] --> [赵|晴唐]
# 094: [gong sun | yun xiu       ] --> [宫孙|云岫]
# 095: [he | zi mo               ] --> [赫|子莫]
# 096: [yuan | jing hong         ] --> [渊|惊鸿]
# 097: [kong | xing he           ] --> [孔|星河]
# 098: [sheng | zhang feng       ] --> [盛|张凤]
# 099: [li | xuan heng           ] --> [璃|轩衡]
