# %% [markdown]
# ![image.png](attachment:image.png)

# %%
zhs = open('data/names1/names1.txt','r').read().splitlines()
pinyins = open('data/names1/names1_pinyin_components.txt','r').read().splitlines()
pinyins_to_chars = open('data/names1/pinyin_components_to_hanzi_chars1.txt','r').read().splitlines()

i=0
for zh,p,ch in zip(zhs[:10],pinyins[:10],pinyins_to_chars[:10]):
    print(f'{i:02d}: {zh:5} {p:25} {ch}')
    i+=1

len(zhs),len(pinyins),len(pinyins_to_chars)
# Out:
# 00: 倪|子宁  n i | z i n ing           n i	倪
# 01: 宋|云深  s ong | y un sh en        z i	子
# 02: 尤|听澜  y ou | t ing l an         n ing	宁
# 03: 唐|承安  t ang | ch eng _ an       s ong	宋
# 04: 龙|长宁  l ong | zh ang n ing      y un	云 韵
# 05: 田|清玄  t ian | q ing x uan       sh en	深 沈 申
# 06: 柯|川   k e | ch uan              y ou	尤 游
# 07: 郑|灵微  zh eng | l ing w ei       t ing	听
# 08: 任|瑶音  r en | y ao y in          l an	澜 岚 兰
# 09: 汪|音   w ang | y in              t ang	唐 棠 汤
# (12000, 12000, 188)

# %%
# set(''.join(pinyins))
tokens = [p.split() for p in pinyins]
token_list = sorted({'.'} | {t for token in tokens for t in token})
token_list_len = len(token_list)

stoi = {s:i for i,s in enumerate(token_list)}
itos = {i:s for i,s in enumerate(token_list)}


print(pinyins[:2])
print(tokens[:2])
print(sorted(set([t for token in tokens[:2] for t in token])))

print(itos)
print(stoi)
print(token_list_len)
# Out:
# ['n i | z i n ing', 's ong | y un sh en']
# [['n', 'i', '|', 'z', 'i', 'n', 'ing'], ['s', 'ong', '|', 'y', 'un', 'sh', 'en']]
# ['en', 'i', 'ing', 'n', 'ong', 's', 'sh', 'un', 'y', 'z', '|']
# {0: '.', 1: '_', 2: 'a', 3: 'ai', 4: 'an', 5: 'ang', 6: 'ao', 7: 'b', 8: 'c', 9: 'ch', 10: 'd', 11: 'e', 12: 'ei', 13: 'en', 14: 'eng', 15: 'f', 16: 'g', 17: 'h', 18: 'i', 19: 'ia', 20: 'ian', 21: 'iang', 22: 'iao', 23: 'ie', 24: 'in', 25: 'ing', 26: 'iong', 27: 'iu', 28: 'j', 29: 'k', 30: 'l', 31: 'm', 32: 'n', 33: 'o', 34: 'ong', 35: 'ou', 36: 'p', 37: 'q', 38: 'r', 39: 's', 40: 'sh', 41: 't', 42: 'u', 43: 'ua', 44: 'uai', 45: 'uan', 46: 'uang', 47: 'ue', 48: 'ui', 49: 'un', 50: 'uo', 51: 'v', 52: 'w', 53: 'x', 54: 'y', 55: 'z', 56: 'zh', 57: '|'}
# {'.': 0, '_': 1, 'a': 2, 'ai': 3, 'an': 4, 'ang': 5, 'ao': 6, 'b': 7, 'c': 8, 'ch': 9, 'd': 10, 'e': 11, 'ei': 12, 'en': 13, 'eng': 14, 'f': 15, 'g': 16, 'h': 17, 'i': 18, 'ia': 19, 'ian': 20, 'iang': 21, 'iao': 22, 'ie': 23, 'in': 24, 'ing': 25, 'iong': 26, 'iu': 27, 'j': 28, 'k': 29, 'l': 30, 'm': 31, 'n': 32, 'o': 33, 'ong': 34, 'ou': 35, 'p': 36, 'q': 37, 'r': 38, 's': 39, 'sh': 40, 't': 41, 'u': 42, 'ua': 43, 'uai': 44, 'uan': 45, 'uang': 46, 'ue': 47, 'ui': 48, 'un': 49, 'uo': 50, 'v': 51, 'w': 52, 'x': 53, 'y': 54, 'z': 55, 'zh': 56, '|': 57}
# 58

# %%
# 训练集 80% -> 优化模型权重
# 验证集 10% -> 调整超参数
# 测试集 10% -> 测试模型泛化性和准确率
import torch
import torch.nn.functional as F

block_size = 3 # 上下文长度
def build_dataset(data):
    X,Y = [],[]
    for t in data:
        # print(['.']*block_size + t + ['.'])
        # print(t + ['.'])

        str1 = ['.']*block_size + t + ['.']
        str2 = t + ['.']

        i=0
        for _,y in zip(str1,str2):
            # print(str1[i:i+block_size],y)
            # print([stoi[str1[j]] for j in range(i,i+block_size)],stoi[y])
            X.append([stoi[str1[j]] for j in range(i,i+block_size)])
            Y.append(stoi[y])
            i+=1


    X=torch.tensor(X)
    Y=torch.tensor(Y)
    print(X.shape,Y.shape,X.dtype,Y.dtype)
    return X,Y

import random
random.seed(0)
random.shuffle(tokens)
n1 = int(0.8*len(tokens))
n2 = int(0.9*len(tokens))

Xtr,Ytr   = build_dataset(tokens[:n1])
Xdev,Ydev = build_dataset(tokens[n1:n2])
Xte,Yte   = build_dataset(tokens[n2:])
# Out:
# torch.Size([74388, 3]) torch.Size([74388]) torch.int64 torch.int64
# torch.Size([9262, 3]) torch.Size([9262]) torch.int64 torch.int64
# torch.Size([9266, 3]) torch.Size([9266]) torch.int64 torch.int64

# %%
embedding_dim = 2
hidden_dim = 100
batch_size = 32

g = torch.Generator().manual_seed(0)
E = torch.randn((token_list_len, embedding_dim),generator=g)
W1 = torch.randn((block_size*embedding_dim, hidden_dim),generator=g)
b1 = torch.randn(hidden_dim,generator=g)
W2 = torch.randn((hidden_dim,token_list_len),generator=g)
b2 = torch.randn(token_list_len,generator=g)

parameters=[E,W1,b1,W2,b2]
for p in parameters:
    p.requires_grad = True
lr_base = 0.3

# %%
def get_lr(lr_base,i,iter_count):
    if i<iter_count/2:
        return lr_base
    if i>iter_count-iter_count/4:
        return lr_base/100
    return lr_base/10

get_lr(0.3,0,200000),get_lr(0.3,99999,200000),get_lr(0.3,100000,200000),get_lr(0.3,150000,200000),get_lr(0.3,150001,200000)
# Out:
# (0.3, 0.3, 0.03, 0.03, 0.003)

# %%
# train
iter_count = 200000
stepi = []
lossi = []
for i in range(iter_count):
    # forward pass
    batch_idxs = torch.randint(0,Xtr.shape[0],(batch_size,))
    emb = E[Xtr[batch_idxs]]
    h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
    logits = h@W2+b2
    loss = F.cross_entropy(logits,Ytr[batch_idxs])

    #backward pass
    for p in parameters:
        p.grad = None
    loss.backward()

    # update
    lr = get_lr(lr_base,i,iter_count)
    for p in parameters:
        p.data += -lr*p.grad
    
    # track stats
    stepi.append(i)
    lossi.append(loss.item())

    # print
    if(i%1000==0):
        print(f'{i:6d}: loss={loss.item()}')
# Out:
#      0: loss=20.46116828918457
#   1000: loss=1.8383148908615112
#   2000: loss=1.942634105682373
#   3000: loss=2.036358594894409
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(stepi,lossi)

emb = E[Xtr]
h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
logits = h@W2+b2
loss = F.cross_entropy(logits,Ytr)
print(loss)

emb = E[Xdev]
h = torch.tanh(emb.view(-1,block_size*embedding_dim)@W1+b1)
logits = h@W2+b2
loss = F.cross_entropy(logits,Ydev)
loss
# Out:
# tensor(1.3391, grad_fn=<NllLossBackward0>)
# tensor(1.3620, grad_fn=<NllLossBackward0>)

# %%
plt.figure(figsize=(8,8))
plt.scatter(E[:,0].data,E[:,1].data,s=200)
for i in range(E.shape[0]):
    plt.text(E[i,0].item(),E[i,1].item(),itos[i],ha='center',va='center',color='white')
plt.grid('minor')

# %%
# 采样
g = torch.Generator().manual_seed(0)

samples=[]
names=[]
for i in range(100):
    has_first_name = False
    out = []
    context = [0]*3  #'...'起始
    # print(context)
    while True:
        emb = E[torch.tensor([context])]

        # print(emb)

        h = torch.tanh(emb.view(1,-1)@W1+b1)
        # print(h.shape)
        logits = h@W2+b2
        probs = F.softmax(logits,dim=1)
        # print(probs.shape, probs[0].sum())
        ix = torch.multinomial(probs,num_samples=1,replacement=True,generator=g).item()
        char = itos[ix]
        # 确保每次采样一个姓氏一个名
        if char=='.':
            if has_first_name:
                break
            else:
                continue
        if char=='|':
            if not has_first_name:
                has_first_name = True
            else:
                break 
        context = context[1:]+[ix]       
        out.append(char)
        
        # #小于5个字
        # if len(out)>=4*2 :
        #     break
    samples.append(out)
    

i=0        
for o in samples:
    print(f'{i:03d}:{o}')
    i+=1
# Out:
# 000:['t', 'an', '|', 'zh', 'i', 'm', 'ing']
# 001:['sh', 'i', '|', 'm', 'o', 'b', 'ai']
# 002:['l', 'i', '|', 'x', 'uan', 'h', 'eng']
# 003:['zh', 'eng', '|', 'h', 'uai', 'n', 'ing']
# 004:['b', 'ai', '|', 'w', 'an']
# 005:['d', 'ai', '|', 'q', 'ing', 'q', 'iu']
# 006:['d', 'uan', '|', 'm', 'ing', 'zh', 'ao']
# 007:['x', 'ue', '|', 'y', 'an']
# 008:['j', 'iang', '|', 'y', 'u', 'w', 'en']
# 009:['m', 'o', '|', 'y', 'in']
# 010:['t', 'ong', '|', 'x', 'ue', 'q', 'ing']
# 011:['q', 'u', '|', 'zh', 'ang', 'm', 'ing']
# 012:['b', 'ai', 'l', 'i', '|', 'l', 'in']
# 013:['j', 'iang', '|', 'q', 'ing', 'x', 'uan']
# 014:['zh', 'ong', 'l', 'i', '|', 'l', 'an']
# 015:['p', 'eng', '|', 'x', 'uan', 'y', 'ue']
# 016:['y', 'uan', '|', '_', 'an']
# 017:['y', 'e', '|', 'j', 'ing', 'n', 'ing']
# 018:['t', 'ian', '|', 'q', 'ing', 'y', 'uan']
# 019:['x', 'ue', '|', 'j', 'ing', 'x', 'ing']
# 020:['l', 'uo', '|', 'j', 'ing', 'x', 'ing']
# 021:['l', 'u', '|', 'zh', 'ang', 'g', 'eng']
# 022:['f', 'eng', '|', 'sh', 'ou', 'zh', 'en']
# 023:['f', 'u', '|', 'q', 'ing', 'n', 'ing']
# 024:['k', 'e', '|', 'q', 'ing', 'y', 'uan']
# 025:['y', 'ao', '|', 't', 'ing', 'l', 'an']
# 026:['zh', 'ao', '|', 'zh', 'ang', 'm', 'ing']
# 027:['l', 'u', '|', 'zh', 'ao', 'h', 'ang']
# 028:['m', 'u', '|', 'q', 'ing', 'm', 'ing']
# 029:['k', 'ong', '|', 'h', 'uan']
# 030:['g', 'e', '|', 'x', 'ue', 't', 'ang']
# 031:['x', 'iao', '|', 'x', 'uan', 'm', 'ing']
# 032:['b', 'i', '|', 'm', 'ing', 'y', 'uan']
# 033:['x', 'iao', '|', 't', 'ing', 'f', 'eng']
# 034:['d', 'i', '|', 'z', 'i', 'n', 'ing']
# 035:['zh', 'ong', 'l', 'i', '|', 'zh', 'ou']
# 036:['h', 'uang', '|', 'l', 'an', 'n', 'ing']
# 037:['d', 'ing', '|', 'h', 'uan']
# 038:['c', 'ao', '|', 'w', 'an', 't', 'ang']
# 039:['j', 'ia', '|', 'l', 'ing', 'q', 'ing']
# 040:['x', 'u', '|', 't', 'ing', 'l', 'an']
# 041:['y', 'in', '|', 'sh', 'ou', 'zh', 'en']
# 042:['zh', 'u', '|', 'y', 'un']
# 043:['n', 'iu', '|', 'x', 'iu', 'w', 'en']
# 044:['w', 'ei', '|', 'ch', 'eng', 'y', 'ing']
# 045:['l', 'iu', '|', 'w', 'an', 'q', 'ing']
# 046:['y', 'u', '|', 'q', 'ing', 'y', 'uan']
# 047:['g', 'uo', '|', 'r', 'uo', 'l', 'an']
# 048:['d', 'ing', '|', 'zh', 'i', 'b', 'ai']
# 049:['g', 'uan', '|', 'b', 'ao', 'p', 'u']
# 050:['zh', 'ang', 's', 'un', '|', 'x', 'i']
# 051:['k', 'ang', '|', 'z', 'i', '_', 'an']
# 052:['g', 'ui', '|', 'y', 'ao', 'y', 'ue']
# 053:['x', 'ue', '|', 'y', 'in']
# 054:['t', 'ian', '|', 'x', 'ue', 't', 'ang']
# 055:['j', 'in', '|', 'x', 'ing', 'h', 'e']
# 056:['w', 'ei', '|', 'x', 'ue', 'q', 'ing']
# 057:['zh', 'eng', '|', 't', 'ing', 'l', 'an']
# 058:['j', 'iang', '|', 'zh', 'ou']
# 059:['b', 'ao', '|', 'x', 'ing', 'h', 'e']
# 060:['d', 'eng', '|', 'y', 'ue']
# 061:['s', 'u', '|', 'h', 'e']
# 062:['s', 'un', '|', 'l', 'an', 'w', 'ei']
# 063:['x', 'ia', '|', 'y', 'un', 'q', 'i']
# 064:['y', 'e', '|', 'zh', 'i', 'm', 'ing']
# 065:['f', 'an', '|', 'g', 'ui', 'y', 'ue']
# 066:['c', 'ai', '|', 'y', 'ao', 'q', 'ing']
# 067:['zh', 'uang', '|', 'h', 'uai', '_', 'an']
# 068:['h', 'e', '|', 'z', 'i', 'q', 'ing']
# 069:['l', 'an', '|', 'w', 'u', 'j', 'iu']
# 070:['zh', 'an', '|', 'y', 'u']
# 071:['y', 'u', '|', 'zh', 'ang', 'l', 'i']
# 072:['d', 'ong', 'f', 'ang', '|', 'z', 'i', 'y', 'uan']
# 073:['l', 'an', '|', 'sh', 'ao', 'b', 'ai']
# 074:['y', 'an', '|', 'x', 'ing', 'l', 'in']
# 075:['h', 'uang', '|', 'z', 'i', 'j', 'in']
# 076:['zh', 'u', 'g', 'e', '|', 'x', 'ing', 'zh', 'ou']
# 077:['b', 'o', '|', 'z', 'i', 'j', 'in']
# 078:['g', 'u', '|', 'w', 'an', 't', 'ang']
# 079:['t', 'ian', '|', 'h', 'an', 'zh', 'ang']
# 080:['y', 'uan', '|', 'y', 'an']
# 081:['w', 'en', 'r', 'en', '|', 'l', 'ing', 'w', 'ei']
# 082:['d', 'uan', 'm', 'u', '|', 't', 'ing', 'x', 'ue']
# 083:['z', 'eng', '|', 'h', 'ang']
# 084:['d', 'ing', '|', 'x', 'uan', 'zh', 'en']
# 085:['zh', 'u', '|', 'sh', 'ao', 'b', 'ai']
# 086:['d', 'ong', 'g', 'uo', '|', 'w', 'u', 'ch', 'en']
# 087:['t', 'ao', '|', 'z', 'i', 'q', 'ing']
# 088:['t', 'ang', '|', 'y', 'u', 'w', 'en']
# 089:['r', 'en', '|', 'x', 'ing', 'h', 'e']
# 090:['zh', 'uang', '|', 'y', 'ue']
# 091:['t', 'ian', '|', 'sh', 'ao', 'b', 'ai']
# 092:['f', 'an', '|', 'x', 'ing', 'zh', 'ou']
# 093:['f', 'u', '|', 'y', 'u', 'x', 'iao']
# 094:['q', 'in', '|', 'y', 'ao', 'q', 'ing']
# 095:['t', 'ang', '|', 'x', 'ing', 'y', 'ao']
# 096:['l', 'u', '|', 'q', 'ing', 'h', 'eng']
# 097:['y', 'e', '|', 'y', 'ao', 'y', 'in']
# 098:['g', 'eng', '|', 'm', 'ing', 'zh', 'ao']
# 099:['n', 'iu', '|', 't', 'ing', 'l', 'an']

# %%
# 解码成中文
INITIALS = {
    '_', 'b','p','m','f','d','t','n','l','g','k','h',
    'j','q','x','r','z','c','s','y','w','zh','ch','sh'
}

FINALS = {
    'a','o','e','i','u','v',
    'ai','ei','ui','ao','ou','iu','ie','ue','er',
    'an','en','in','un','vn',
    'ang','eng','ing','ong',
    'ia','iao','ian','iang','iong',
    'ua','uo','uai','uan','uang'
}
def is_valid(tokens):
    
    # 只能有一个姓氏
    if tokens.count('|') != 1:
        return False

    # 必须有一个姓氏和一个名
    sep = tokens.index('|')
    if sep == 0 or sep == len(tokens) - 1:
        return False

    # 确保声母和韵母配对
    parts = tokens[:sep] + tokens[sep + 1:]
    if len(parts) % 2 != 0:
        return False

    # # 小于5个汉字
    # if len(parts)/2 > 5:
    #     return False

    # 必须在声韵表中
    for i in range(0, len(parts), 2):
        if parts[i] not in INITIALS:
            return False
        if parts[i + 1] not in FINALS:
            return False

    return True


i=0
for flag in [is_valid(o) for o in samples]:
    if not flag:
        print(f'{i}: {samples[i]}')
    
    i+=1

# %%
import random
def load_component_char_mapping(path):
    mapping = {}

    with open(path, encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            key, chars_text = line.split('\t', 1)
            mapping[key] = chars_text.split()

    return mapping

mapping = load_component_char_mapping('data/names1/pinyin_components_to_hanzi_chars1.txt')
print(len(mapping),mapping.get('h an'))

def samples_to_names(samples, mapping, rng=random):
    for i, tokens in enumerate(samples):
        try:
            sep = tokens.index('|')
        except ValueError:
            # 1. 没有 '|' 符号，属于严重格式错误，保留 INVALID
            print(f'{i:03d}: [<Invaild 1: No \'|\' >] --> [<None>]')
            continue

        left_part, right_part = [], []
        valid = True

        for side in (tokens[:sep], tokens[sep + 1:]):
            # 2. 长度不是偶数，属于格式错误，保留 INVALID
            if len(side) % 2 != 0:
                valid = False
                break
            
            l_chars, r_chars = [], []
            for j in range(0, len(side), 2):
                pinyin = side[j] + side[j + 1]
                key = f"{side[j]} {side[j + 1]}"
                choices = mapping.get(key)
                
                # 如果 mapping 里面没有，直接用原始拼音
                if choices:
                    l_chars.append(rng.choice(choices))
                else:
                    l_chars.append(pinyin)
                    
                r_chars.append(pinyin)
            
            left_part.append(''.join(l_chars))
            right_part.append(' '.join(r_chars))

        if not valid:
            print(f'{i:03d}: [<Invaild 2: 声韵母不匹配>] --> [<None>]')
        else:
            print(f'{i:03d}: [{" | ".join(right_part):25}] --> [{"|".join(left_part)}]')

samples_to_names(samples, mapping)
# Out:
# 188 ['含', '韩', '涵', '寒']
# 000: [tan | zhi ming           ] --> [谭|执冥]
# 001: [shi | mo bai             ] --> [时|墨白]
# 002: [li | xuan heng           ] --> [李|玄衡]
# 003: [zheng | huai ning        ] --> [郑|怀宁]
# 004: [bai | wan                ] --> [百|晚]
# 005: [dai | qing qiu           ] --> [戴|青邱]
# 006: [duan | ming zhao         ] --> [端|明昭]
# 007: [xue | yan                ] --> [薛|言]
# 008: [jiang | yu wen           ] --> [姜|尉温]
# 009: [mo | yin                 ] --> [莫|尹]
# 010: [tong | xue qing          ] --> [童|雪晴]
# 011: [qu | zhang ming          ] --> [曲|章冥]
# 012: [bai li | lin             ] --> [白黎|林]
# 013: [jiang | qing xuan        ] --> [江|青轩]
# 014: [zhong li | lan           ] --> [钟里|兰]
# 015: [peng | xuan yue          ] --> [彭|轩岳]
# 016: [yuan | _an               ] --> [袁|安]
# 017: [ye | jing ning           ] --> [夜|景宁]
# 018: [tian | qing yuan         ] --> [田|青远]
# 019: [xue | jing xing          ] --> [雪|惊邢]
# 020: [luo | jing xing          ] --> [洛|景邢]
# 021: [lu | zhang geng          ] --> [芦|长庚]
# 022: [feng | shou zhen         ] --> [凤|守甄]
# 023: [fu | qing ning           ] --> [傅|清宁]
# 024: [ke | qing yuan           ] --> [柯|清远]
# 025: [yao | ting lan           ] --> [遥|听岚]
# 026: [zhao | zhang ming        ] --> [照|长冥]
# 027: [lu | zhao hang           ] --> [卢|赵珩]
# 028: [mu | qing ming           ] --> [牧|晴冥]
# 029: [kong | huan              ] --> [孔|欢]
# 030: [ge | xue tang            ] --> [葛|雪汤]
# 031: [xiao | xuan ming         ] --> [霄|轩明]
# 032: [bi | ming yuan           ] --> [毕|明元]
# 033: [xiao | ting feng         ] --> [霄|听凤]
# 034: [di | zi ning             ] --> [翟|子宁]
# 035: [zhong li | zhou          ] --> [钟黎|舟]
# 036: [huang | lan ning         ] --> [皇|澜宁]
# 037: [ding | huan              ] --> [丁|欢]
# 038: [cao | wan tang           ] --> [曹|万汤]
# 039: [jia | ling qing          ] --> [贾|令青]
# 040: [xu | ting lan            ] --> [许|听兰]
# 041: [yin | shou zhen          ] --> [尹|守甄]
# 042: [zhu | yun                ] --> [诸|韵]
# 043: [niu | xiu wen            ] --> [牛|修文]
# 044: [wei | cheng ying         ] --> [卫|成影]
# 045: [liu | wan qing           ] --> [柳|晚青]
# 046: [yu | qing yuan           ] --> [瑜|清渊]
# 047: [guo | ruo lan            ] --> [郭|若澜]
# 048: [ding | zhi bai           ] --> [丁|知百]
# 049: [guan | bao pu            ] --> [管|包朴]
# 050: [zhang sun | xi           ] --> [张孙|溪]
# 051: [kang | zi _an            ] --> [康|子安]
# 052: [gui | yao yue            ] --> [归|瑶月]
# 053: [xue | yin                ] --> [薛|殷]
# 054: [tian | xue tang          ] --> [田|薛唐]
# 055: [jin | xing he            ] --> [瑾|行禾]
# 056: [wei | xue qing           ] --> [韦|雪清]
# 057: [zheng | ting lan         ] --> [郑|听兰]
# 058: [jiang | zhou             ] --> [江|舟]
# 059: [bao | xing he            ] --> [薄|邢贺]
# 060: [deng | yue               ] --> [邓|岳]
# 061: [su | he                  ] --> [素|赫]
# 062: [sun | lan wei            ] --> [孙|岚魏]
# 063: [xia | yun qi             ] --> [夏|云起]
# 064: [ye | zhi ming            ] --> [夜|执明]
# 065: [fan | gui yue            ] --> [樊|归越]
# 066: [cai | yao qing           ] --> [蔡|摇青]
# 067: [zhuang | huai _an        ] --> [庄|怀安]
# 068: [he | zi qing             ] --> [禾|子晴]
# 069: [lan | wu jiu             ] --> [岚|吴咎]
# 070: [zhan | yu                ] --> [詹|羽]
# 071: [yu | zhang li            ] --> [尉|长李]
# 072: [dong fang | zi yuan      ] --> [董方|子辕]
# 073: [lan | shao bai           ] --> [岚|少柏]
# 074: [yan | xing lin           ] --> [炎|行林]
# 075: [huang | zi jin           ] --> [黄|子衿]
# 076: [zhu ge | xing zhou       ] --> [竹葛|行洲]
# 077: [bo | zi jin              ] --> [卜|子衿]
# 078: [gu | wan tang            ] --> [谷|婉汤]
# 079: [tian | han zhang         ] --> [田|韩章]
# 080: [yuan | yan               ] --> [辕|阎]
# 081: [wen ren | ling wei       ] --> [闻人|令韦]
# 082: [duan mu | ting xue       ] --> [端慕|听雪]
# 083: [zeng | hang              ] --> [曾|珩]
# 084: [ding | xuan zhen         ] --> [丁|轩真]
# 085: [zhu | shao bai           ] --> [诸|少白]
# 086: [dong guo | wu chen       ] --> [东郭|吴尘]
# 087: [tao | zi qing            ] --> [陶|子晴]
# 088: [tang | yu wen            ] --> [唐|瑜闻]
# 089: [ren | xing he            ] --> [任|星和]
# 090: [zhuang | yue             ] --> [庄|月]
# 091: [tian | shao bai          ] --> [田|少白]
# 092: [fan | xing zhou          ] --> [樊|邢洲]
# 093: [fu | yu xiao             ] --> [扶|雨霄]
# 094: [qin | yao qing           ] --> [秦|瑶晴]
# 095: [tang | xing yao          ] --> [汤|邢姚]
# 096: [lu | qing heng           ] --> [路|青衡]
# 097: [ye | yao yin             ] --> [夜|遥殷]
# 098: [geng | ming zhao         ] --> [耿|明照]
# 099: [niu | ting lan           ] --> [牛|听岚]
